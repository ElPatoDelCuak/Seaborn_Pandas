# %% [markdown]
# ## 1. Distribució edat passatgers ##

# %% [markdown]
# ## 2. Mitja de preu ##

# %% [markdown]
# ## 3. % Homes i dones supervivents ##

# %% [markdown]
# ## 4. Quadre estadistic ##
